# %% [markdown]
# # Titanic Survival Classification
#
# This project is to develop a machine learning model to predict whether a passenger survives the Titanic sinking.

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from statsmodels.formula.api import ols
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder, StandardScaler
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay, PrecisionRecallDisplay

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.tree import DecisionTreeClassifier

# This is the function that helps plot feature importance
from xgboost import plot_importance, XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# This module lets us save our models once we fit them.
import pickle

# %% [markdown]
# ### Load Dataset

# %%
gender = pd.read_csv('gender_submission.csv')
training = pd.read_csv('train.csv')
testing = pd.read_csv('test.csv')

# %%
training.info()
training.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
# ...

# %%
testing.info()
testing.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# ...

# %% [markdown]
# The training dataset consists of 891 entries and 12 unique columns with integer, object and float data types, whereas the testing dataset contains 418 entries and 11 unique columns. There are 3 columns in the training set with null values and 2 columns in the testing set with null values.
#
# Here's a quick summary of the columns in the dataset:
#
# - **Survival**: Survival	0 = No, 1 = Yes
# - **Pclass**: Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# - **Sex**: Gender of passenger
# - **Age**: Age in years
# - **Sibsp**: Number of siblings / spouses aboard the Titanic
# - **Parch**: Number of parents / children aboard the Titanic
# - **Ticket**: Ticket number
# - **Fare**: Passenger fare
# - **Cabin**: Cabin number
# - **Embarked**:	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# ## Data Cleaning and Preparation

# %%
df = pd.concat([training.drop(columns=['Survived']), testing], axis=0, sort=False)

# %%
# Function for data cleaning
def clean(df):
    # Removing unnecessary columns
    df = df.drop(columns = {'PassengerId'}) 
    
    # Filling null values
    df.Age = df.Age.fillna(df.Age.median()) 
    df.Embarked = df.Embarked.fillna(df.Embarked.mode())
    df.Fare = df.Fare.fillna(df.Fare.median())

    # Changing column to binary
    df.Sex = np.where(df.Sex == 'male', 1, 0)

    return df

# %%
df = clean(df)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.describe(include = 'all')
# Out:
#              Pclass                  Name          Sex          Age  \
# count   1309.000000                  1309  1309.000000  1309.000000
# unique          NaN                  1307          NaN          NaN
# top             NaN  Connolly, Miss. Kate          NaN          NaN
# freq            NaN                     2          NaN          NaN
# mean       2.294882                   NaN     0.644003    29.503186
# std        0.837836                   NaN     0.478997    12.905241
# min        1.000000                   NaN     0.000000     0.170000
# 25%        2.000000                   NaN     0.000000    22.000000
# 50%        3.000000                   NaN     1.000000    28.000000
# 75%        3.000000                   NaN     1.000000    35.000000
# max        3.000000                   NaN     1.000000    80.000000
#
#               SibSp        Parch    Ticket         Fare        Cabin Embarked
# ...

# %% [markdown]
# The average age of the passengers on the Titanic was approximately 29 years old with the oldest person being 80 years old and the youngest being a baby of 2 months old. The average price of fare to board the Titanic was around 33.28 dollars. Some passengers came aboard for free and the most expensive ticket costs over 500 dollars.

# %%
training.Survived.value_counts(normalize = True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %% [markdown]
# The survival rate of the Titanic was approximately 38%.

# %%
# Plotting heatmap of correlation between independent and dependent variables
plt.figure(figsize = (12,4))
plt.subplot(1,2,1)
corr_matrix = df.drop(columns = {'Embarked', 'Name', 'Ticket', 'Cabin'}).corr(method = 'pearson')
sns.heatmap(corr_matrix, annot = True, cmap = 'Blues')
plt.title('Correlation between independent \nvariables')

# plt.subplot(1,2,2)
# corr_matrix = training.drop(columns = {'Embarked', 'Name', 'Ticket', 'Cabin'}).corr(method = 'pearson')
# corr_target = corr_matrix[['Survived']].drop(labels = ['Survived'])
# sns.heatmap(corr_target, annot= True, cmap = 'Blues')
# plt.title('Correlation between independent and \ndependent variables')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Correlation between independent \nvariables')

# %% [markdown]
# None of the independent variables have high correlation.

# %% [markdown]
# ## Feature Engineering

# %%
df.head()
# Out:
#    Pclass                                               Name  Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    1  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2       3                             Heikkinen, Miss. Laina    0  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4       3                           Allen, Mr. William Henry    1  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Training data

# %%
def feature_engineer(df):

    # Family size
    # df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
    # df['IsAlone'] = (df['FamilySize'] == 1).astype(int)

    # Age bins
    # df['AgeBin'] = pd.cut(df['Age'], bins=[0, 12, 18, 35, 60, 80], 
    #                       labels=['Child','Teen','YoungAdult','Adult','Senior'])

    # CabinRoom
    # df['CabinRoom'] = df.Cabin.str[0]
    # df.CabinRoom = df.CabinRoom.fillna('Unknown')

    # TicketPrefix
    # df['TicketPrefix'] = df['Ticket'].str.replace('[0-9]+', '', regex=True).str.replace('[^A-Za-z]', '', regex=True)
    # df['TicketPrefix'] = df['TicketPrefix'].replace('', 'None')  # fill empty with 'None'

    # Title
    # df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
    # df['Title'] = df['Title'].replace(['Lady','Countess','Capt','Col','Don','Dr',
    #                                    'Major','Rev','Sir','Jonkheer','Dona'],'Rare')
    # df['Title'] = df['Title'].replace({'Mlle':'Miss', 'Ms':'Miss', 'Mme':'Mrs'})
    
    # One-hot encoding
    embarked_encoded = pd.get_dummies(df[['Embarked']])
    df = pd.concat([df, embarked_encoded], axis=1)

    # Drop original categorical columns
    df.drop(columns=['Name', 'Ticket', 'Cabin', 'Embarked'], inplace=True)

    return df

# %%
df = feature_engineer(df)

# %%
x_train = df.iloc[:len(training), :]
x_test = df.iloc[len(training):, :]
y_train = training['Survived']

# %% [markdown]
# ## Model Evaluation

# %%
def make_results(model_name:str, model_object, metric:str):
    '''
    Arguments:
        model_name (string): what you want the model to be called in the output table
        model_object: a fit GridSearchCV object
        metric (string): precision, recall, f1, or accuracy

    Returns a pandas df with the F1, recall, precision, and accuracy scores
    for the model with the best mean 'metric' score across all validation folds.
    '''

    # Create dictionary that maps input metric to actual metric name in GridSearchCV
    metric_dict = {'precision': 'mean_test_precision',
                   'recall': 'mean_test_recall',
                   'f1': 'mean_test_f1',
                   'accuracy': 'mean_test_accuracy',
                   }

    # Get all the results from the CV and put them in a df
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(metric) score
    best_estimator_results = cv_results.iloc[cv_results[metric_dict[metric]].idxmax(), :]

    # Extract accuracy, precision, recall, and f1 score from that row
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy

    # Create table of results
    table = pd.DataFrame({'model': [model_name],
                          'precision': [precision],
                          'recall': [recall],
                          'F1': [f1],
                          'accuracy': [accuracy],
                          },
                         )

    return table

# %% [markdown]
# ### Splitting data

# %%
# X = train.drop(columns = 'Survived').copy()
# y = train.Survived

# x_train, x_test, y_train, y_test = train_test_split(X, y, stratify = y, random_state = 42, train_size = 0.7)

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression(random_state = 42)

cv_params = {'penalty': ['l2'],
             'C': [0.1,1,2],
             'max_iter': [200,300]
             }

# Define a list of scoring metrics to capture
scoring = ['accuracy', 'precision', 'recall', 'f1']

# Instantiate the GridSearchCV object
lr_cv = GridSearchCV(lr, cv_params, scoring=scoring, cv=4, refit='f1')
# lr_cv.fit(x_train, y_train)
# result_1 = make_results('Logistic Regression', lr_cv, 'f1')

# %% [markdown]
# ### Random Forest Classifier

# %%
rf = RandomForestClassifier(random_state = 42)

cv_params = {'max_depth': [None],
             'max_features': [None],
             'max_samples': [0.5],
             'min_samples_leaf': [2],
             'min_samples_split': [2],
             'n_estimators': [200, 300],
             }

# Instantiate the GridSearchCV object
rf_cv = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='f1')
rf_cv.fit(x_train, y_train)

# rf_result = make_results('Random Forest', rf_cv, 'f1')
# result_2 = pd.concat([result_1, rf_result],axis = 0)
# result_2.sort_values(by = 'F1', ascending = False)
# Out:
# GridSearchCV(cv=4, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None], 'max_features': [None],
#                          'max_samples': [0.5], 'min_samples_leaf': [2],
#                          'min_samples_split': [2], 'n_estimators': [200, 300]},
#              refit='f1', scoring=['accuracy', 'precision', 'recall', 'f1'])

# %%
rf.fit(x_train, y_train)
rf_importances = pd.Series(rf.feature_importances_, index = x_train.columns)

plt.figure(figsize=(8,4))
rf_importances.sort_values(ascending = True).plot(kind='barh')
plt.title("Random Forest - Top 15 Feature Importances")
plt.ylabel("Importance")
plt.show()

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
# %%time
gbr = GradientBoostingClassifier(random_state = 42)

cv_params = {'n_estimators': [380, 400, 420],
             'max_depth': [None],
             'min_samples_split': [4, 6, 8],
             'min_samples_leaf':[1, 2, 5],
             'max_samples': [1.0]
             }

# Instantiate the GridSearchCV object
gbr_cv = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='f1')
gbr_cv.fit(x_train, y_train)
# Out:
# CPU times: total: 57 s
# Wall time: 57.1 s
# GridSearchCV(cv=4, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None], 'max_samples': [1.0],
#                          'min_samples_leaf': [1, 2, 5],
#                          'min_samples_split': [4, 6, 8],
#                          'n_estimators': [380, 400, 420]},
#              refit='f1', scoring=['accuracy', 'precision', 'recall', 'f1'])

# %%
gbr_cv.best_params_
# Out:
# {'max_depth': None,
#  'max_samples': 1.0,
#  'min_samples_leaf': 2,
#  'min_samples_split': 6,
#  'n_estimators': 380}

# %%
# gbr_result = make_results('Gradient Boosting', gbr_cv, 'f1')
# result_3 = pd.concat([result_2, gbr_result],axis = 0)
# result_3.sort_values(by = 'F1', ascending = False)

# %%
gbr.fit(x_train, y_train)
gbr_importances = pd.Series(gbr.feature_importances_, index = x_train.columns)

plt.figure(figsize=(8,4))
gbr_importances.sort_values(ascending = True).plot(kind='barh')
plt.title("Gradient Boosting - Top 15 Feature Importances")
plt.ylabel("Importance")
plt.show()

# %% [markdown]
# ### Decision Tree Classifier

# %%
dtr = DecisionTreeClassifier(random_state = 42)

cv_params = {'max_depth': [None],
             'max_features': [None],
             'min_samples_leaf': [2,4,6],
             'min_samples_split': [2,4,6]
             }

# Instantiate the GridSearchCV object
dtr_cv = GridSearchCV(dtr, cv_params, scoring=scoring, cv=4, refit='f1')
# dtr_cv.fit(x_train, y_train)

# dtr_result = make_results('Decision Tree', dtr_cv, 'f1')
# result_4 = pd.concat([result_3, dtr_result],axis = 0)
# result_4.sort_values(by = 'F1', ascending = False)

# %%
dtr.fit(x_train, y_train)
dtr_importances = pd.Series(dtr.feature_importances_, index = x_train.columns)

# %% [markdown]
# ### XGBoost

# %%
xgb = XGBClassifier(objective='binary:logistic', random_state=42)

# 2. Create a dictionary of hyperparameters to tune
cv_params = {'max_depth': [10],
             'min_child_weight': [3],
             'learning_rate': [0.1,0.3],
             'n_estimators': [50]
             }


# 4. Instantiate the GridSearchCV object
xgb_cv = GridSearchCV(xgb, cv_params, scoring=scoring, cv=4, refit='recall')

xgb_cv.fit(x_train, y_train)

# xgb_result = make_results('XGBoost', xgb_cv, 'recall')
# result_5 = pd.concat([result_4, xgb_result],axis = 0)
# result_5.sort_values(by = 'recall', ascending = False)
# Out:
# GridSearchCV(cv=4,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
# ...

# %%
xgb.fit(x_train, y_train)
xgb_importances = pd.Series(xgb.feature_importances_, index = x_train.columns)

# %%
plt.figure(figsize=(17,8), facecolor = 'aliceblue')
plt.suptitle('Top Important Features for Each Model', y = 0.96, fontsize = 16)
plt.subplots_adjust(hspace = 0.35, wspace = 0.2)

plt.subplot(2,2,1)
gbr_importances.sort_values(ascending = True).plot(kind='barh')
plt.title("Gradient Boosting")
plt.xlabel("Importance")

plt.subplot(2,2,2)
rf_importances.sort_values(ascending = True).plot(kind='barh')
plt.title("Random Forest")
plt.xlabel("Importance")

plt.subplot(2,2,3)
dtr_importances.sort_values(ascending = True).plot(kind='barh')
plt.title("Decision Tree")
plt.xlabel("Importance")

plt.subplot(2,2,4)
xgb_importances.sort_values(ascending = True).plot(kind='barh')
plt.title("XGBoost")
plt.xlabel("Importance")
plt.show()

# %% [markdown]
# ## Model Selection

# %%
def get_test_scores(model_name:str, preds, y_test_data):
    '''
    Generate a table of test scores.

    In:
        model_name (string): Your choice: how the model will be named in the output table
        preds: numpy array of test predictions
        y_test_data: numpy array of y_test data

    Out:
        table: a pandas df of precision, recall, f1, and accuracy scores for your model
    '''
    accuracy = accuracy_score(y_test_data, preds)
    precision = precision_score(y_test_data, preds)
    recall = recall_score(y_test_data, preds)
    f1 = f1_score(y_test_data, preds)

    table = pd.DataFrame({'model': [model_name],
                          'precision': [precision],
                          'recall': [recall],
                          'F1': [f1],
                          'accuracy': [accuracy]
                          })

    return table

# %%
best_model_gbr = gbr_cv.best_estimator_

best_model_gbr.fit(x_train, y_train)
# y_pred = best_model_gbr.predict(x_test)

# best_gbr_result = get_test_scores('Best GBR', y_pred, y_val)
# result_6 = pd.concat([result_5, best_gbr_result],axis = 0)
# result_6.sort_values(by = 'F1', ascending = False)
# Out:
# RandomForestClassifier(max_samples=1.0, min_samples_leaf=2, min_samples_split=6,
#                        n_estimators=400, random_state=42)

# %%
best_model_xg = xgb_cv.best_estimator_

# best_model_xg.fit(x_train, y_train)
# y_pred = best_model_xg.predict(x_val)

# best_xg_result = get_test_scores('Best XG', y_pred, y_val)
# result_7 = pd.concat([result_6, best_xg_result],axis = 0)
# result_7.sort_values(by = 'F1', ascending = False)

# %% [markdown]
# ### Stacking

# %%
# from sklearn.model_selection import StratifiedKFold

# base_learners = [
#     ('lr', LogisticRegression(max_iter=500, solver='lbfgs')),
#     ('rf', RandomForestClassifier(n_estimators=200, random_state=42)),
#     ('gb', GradientBoostingClassifier(n_estimators=200, random_state=42))
# ]

# # Stacking classifier
# stack_model = StackingClassifier(
#     estimators=base_learners,
#     final_estimator=LogisticRegression(max_iter=500),
#     cv=StratifiedKFold(n_splits=10)
# )

# stack_model.fit(x_train, y_train)
# y_pred = stack_model.predict(x_test)

# print("Stacking Accuracy:", accuracy_score(y_test, y_pred))

# Cross-validation score (more reliable)
# cv_scores = cross_val_score(stack_model, X, y, cv=5, scoring='accuracy')
# print("CV Mean Accuracy:", cv_scores.mean())

# %% [markdown]
# ### Predicting test results

# %%
y_pred_test = best_model_gbr.predict(x_test)

# %%
survival_score = pd.Series(y_pred_test)
final_df = pd.concat([testing.PassengerId, survival_score], axis = 1)

# Renaming columns
final_df.rename(columns = {0:'Survived'}, inplace = True)
final_df.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %% [markdown]
# ### Exporting results

# %%
import os
path = r'C:\Users\user\Downloads'
final_df.to_csv(os.path.join(path,r'predicted_survival.csv'))
